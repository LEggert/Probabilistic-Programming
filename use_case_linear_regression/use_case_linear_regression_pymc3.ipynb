# %% [markdown]
# This case study follows these resources:
# + https://github.com/justmarkham/DAT5/blob/master/notebooks/09_linear_regression.ipynb
# + https://pymc-devs.github.io/pymc3/notebooks/getting_started.html#A-Motivating-Example:-Linear-Regression
# + https://pymc-devs.github.io/pymc3/notebooks/GLM-linear.html

# %% [markdown]
# ### Setup the system

# %%
# %matplotlib inline

import pymc3             as pm
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Access the data

# %% [markdown]
# Read in the data.

# %%
df_data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)

# %% [markdown]
# Initial look at the data.

# %%
df_data.shape
# Out:
# (200, 4)

# %%
df_data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# Visualize relationships.

# %%
_ = sns.pairplot(df_data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', size=7, aspect=0.7)

# %% [markdown]
# Define predictor variable and outcome variable.

# %%
X = df_data.loc[: , "TV"].values
Y = df_data.loc[: , "Sales"].values

# %% [markdown]
# ### Specify & fit the model

# %%
# Instantiate new model container.
lin_reg_model = pm.Model() 

# Specify model.
with lin_reg_model:

    # Define a-priori probability distributions for unknown model parameters.
    intercept = pm.Normal(     'Intercept', mu=0, sd=20)          # intercept
    beta      = pm.Normal(     'beta',      mu=0, sd=20)          # coefficients
    sigma     = pm.HalfCauchy( 'sigma',     beta=10, testval=1.)  # variance of predicted value
    
    # Expected value of outcome.
    mu = intercept + beta*X
    
    # Likelihood (sampling distribution) of observations.
    Y_obs = pm.Normal('Y_obs', mu=mu, sd=sigma, observed=Y)
    
    # Inference.
    trace = pm.sample(3000) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|█████████▉| 3483/3500 [00:11<00:00, 438.97it/s]/Users/Lucas/anaconda/envs/py36/lib/python3.6/site-packages/pymc3/step_methods/hmc/nuts.py:451: UserWarning: The acceptance probability in chain 0 does not match the target. It is 0.905610191285, but should be close to 0.8. Try to increase the number of tuning steps.
#   % (self._chain_id, mean_accept, target_accept))
# 100%|██████████| 3500/3500 [00:11<00:00, 303.92it/s]

# %% [markdown]
# ### Analyze the model

# %%
pm.summary(trace)
# Out:
# Intercept:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   7.013            0.451            0.012            [6.140, 7.903]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   6.131          6.707          7.004          7.318          7.900
#
#
# beta:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.048            0.003            0.000            [0.042, 0.052]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.042          0.046          0.048          0.049          0.053
#
#
# sigma:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   3.274            0.170            0.004            [2.958, 3.627]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   2.954          3.153          3.268          3.384          3.626

# %%
_ = pm.traceplot(trace)

# %% [markdown]
# Plot the posterior predictive distribution.

# %%
_ = pm.plot_posterior(trace)
